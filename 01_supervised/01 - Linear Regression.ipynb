# %% [markdown]
# ## 📈 01 — Linear Regression
#
# **What it does:** Predicts a continuous output value based on input features.
# **Best used when:** Relationship between input and output is roughly linear.
# **Dataset:** California Housing / Boston Housing
# **Algorithm type:** Supervised → Regression
# **Key metric:** R² Score, MSE
